# %% [markdown]
# <a href="https://colab.research.google.com/github/JazJaz426/Honours/blob/main/Honours_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # come back to retrain resnet50

# %%
# cd '/content/drive/MyDrive/honours_code_final'

# %%
# !python main_test_T.py --noise_type random_label2 --n_epoch 100 --resume

# %% [markdown]
# # Resnet18

# %%
cd '/content/drive/MyDrive/honours_code_final_resnet18'
# Out:
# /content/drive/MyDrive/honours_code_final_resnet18

# %%
# !python main_clean_classifier.py --noise_type clean_label --n_epoch 50 --resume
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified
# ==> Building model..
# ==> Resuming from checkpoint..
#
# Epoch: 195
#  [================================================================>]  Step: 446ms | Tot: 19s330ms | Loss: 0.002 | Acc: 100.000% (45000/45000) 352/352
#  [===============================================================>.]  Step: 73ms | Tot: 758ms | Loss: 0.145 | Acc: 96.180% (4809/5000) 40/40
# Saving..
#
# Epoch: 196
#  [================================================================>]  Step: 34ms | Tot: 18s954ms | Loss: 0.002 | Acc: 99.998% (44999/45000) 352/352
#  [===============================================================>.]  Step: 5ms | Tot: 691ms | Loss: 0.145 | Acc: 96.160% (4808/5000) 40/40
#
# Epoch: 197
#  [================================================================>]  Step: 35ms | Tot: 18s939ms | Loss: 0.002 | Acc: 99.993% (44997/45000) 352/352
# ...

# %%
# !python main_noisy_classifier.py --noise_type random_label1 --n_epoch 30
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Loaded random_label1 from ./data/CIFAR-10_human.pt.
# The overall noise rate is 0.17234000000000005
# noisy labels loaded from ./data/CIFAR-10_human.pt
# Files already downloaded and verified
# Loaded random_label1 from ./data/CIFAR-10_human.pt.
# The overall noise rate is 0.17234000000000005
# noisy labels loaded from ./data/CIFAR-10_human.pt
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
#  [================================================================>]  Step: 159ms | Tot: 11s886ms | Loss: 0.813 | Acc: 82.449% (37102/45000) 352/352
#  [===============================================================>.]  Step: 97ms | Tot: 1s355ms | Loss: 0.849 | Acc: 80.420% (4021/5000) 40/40
# Saving..
#
# Epoch: 1
#  [================================================================>]  Step: 22ms | Tot: 11s769ms | Loss: 0.781 | Acc: 82.784% (37253/45000) 352/352
# ...

# %%
# !python main_test_T.py --noise_type random_label1 --n_epoch 200
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Loaded random_label1 from ./data/CIFAR-10_human.pt.
# The overall noise rate is 0.17234000000000005
# noisy labels loaded from ./data/CIFAR-10_human.pt
# Files already downloaded and verified
# Loaded random_label1 from ./data/CIFAR-10_human.pt.
# The overall noise rate is 0.17234000000000005
# noisy labels loaded from ./data/CIFAR-10_human.pt
# Files already downloaded and verified
# ==> Building model..
#
# Epoch: 0
#  [================================================================>]  Step: 243ms | Tot: 19s445ms | Loss: 2.184 | Acc: 23.220% (10449/45000) 352/352
#  [===============================================================>.]  Step: 7ms | Tot: 705ms | Loss: 2.127 | Acc: 28.160% (1408/5000) 40/40
# Saving..
#
# Epoch: 1
#  [================================================================>]  Step: 35ms | Tot: 19s243ms | Loss: 2.081 | Acc: 29.756% (13390/45000) 352/352
# ...
